# %%
import pandas as pd

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
data = pd.read_csv('youtubers.csv', encoding='ISO-8859-1')

# %%
print(data.columns)
# Out:
# Index(['Rank', 'Youtuber', 'Subscribers', 'Video Views', 'Video Count',
#        'Category', 'Started'],
#       dtype='object')

# %%
X = data[['Subscribers', 'Video Count', 'Video Views']]
y = data['Rank']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
print('MSE:', mean_squared_error(y_test, y_pred))
# Out:
# MSE: 65757.56401655811

# %%
print('R^2:', r2_score(y_test, y_pred))
# Out:
# R^2: 0.17297327414649022

# %%
#აღწერა: ამ ამოცანის ფარგლებში, გამოვიყენებთ მრავალცვლად რეგრესიას, რო გამოვთვალოთ მონაცემთა დამოკიდებულება რამდენიმე ცვლადის მიმართ.
